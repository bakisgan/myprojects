# %%
class projem():

    import csv   
    
    def __init__(self,dosya_yeri_adi):
        self.dya=dosya_yeri_adi
        
        with open(self.dya, 'r') as f:
            d_reader = csv.DictReader(f)
            
            
    def baslikyazdir(self):
        headers = d_reader.fieldnames
        print(headers)
    
    def satir_sutun(self):
        file=open(self.dya)
        reader=csv.reader(file)
        lines=len(list(reader))
        
        headers = d_reader.fieldnames
        print("(",lines-1,",",len(headers),")", sep="")
        
    def sutunyazdir(self,sutun):
        with open(self.dya, 'r') as f:
            d_reader = csv.DictReader(f)
            data = {}
            for row in d_reader:
                 for header, value in row.items():
                    try:
                        data[header].append(value)
                    except KeyError:
                        data[header] = [value]
            print(*data[sutun],sep="\n")
    
    def benzersiz(self,sutun):
        with open(self.dya, 'r') as f:
            d_reader = csv.DictReader(f)
            data = {}
            for row in d_reader:
                 for header, value in row.items():
                    try:
                        data[header].append(value)
                    except KeyError:
                        data[header] = [value]
            benz=set(data[sutun])
            print(*benz,sep="\n")
        
    def boyut(self):
        with open(self.dya, 'r') as f:
            d_reader = csv.DictReader(f)
            headers = d_reader.fieldnames
            data = {}
            for row in d_reader:
                 for header, value in row.items():
                    try:
                        data[header].append(value)
                    except KeyError:
                        data[header] = [value]
            for y in headers:
                print(type(data[y][1]))
